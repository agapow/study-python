# %% [markdown]
# # Aim

# %% [markdown]
# Some notes about using Bokeh for visualisation. Note that there is an R compatibility layer.
#
# Environment: Python3.6 (bokeh-py3)

# %% [markdown]
# # Notes

# %% [markdown]
# ## Concepts

# %% [markdown]
# Bokeh is based around a set of idioms:
#
# * A **plot** (or confusingly sometimes *figures*) is what you draw on. It has axes, labels, legends, scales and so on. Think of it as everything a plot has that isn't the data.
# * **Glyphs** are the drawing primitives: lines, circles, etc. Again, confusingly, Bokeh also talks of *markers*.
# * A **renderer** is the single drawing call, that may actually draw a number of things
# * Plots can be decorated with **guides** (visual depections of distance like grids and axes) and **annotations** (labels, legends, etc.)
# * **Ranges** are what you expect. Bokeh autogenerates these but they can also be converted from obvious pairs like `(0, 10)` or `[-0.5, 0.75]`.
# * A plot is thus a collection (graph) of objects that may be named, selected (by type or name) and manipulated.
# * Colours can be expressed as:
#   * named CSS colors, e.g 'green', 'indigo'
#   * RGB(A) hex value, e.g., '#FF0000', '#44444444'
#   * 3-tuples of integers (r,g,b) between 0 and 255
#   * 4-tuple of (r,g,b,a) where r, g, b are integers between 0 and 255 and a is a floating point value between 0 and 1

# %% [markdown]
# ## Basic use

# %% [markdown]
# A simple example, taken from the Bokeh quickstart. This produces a nice figure (zoomable, pannable, saveable) inline:

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook

# the data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# output inline to notebook
# You can also use Apache Zepplin notebooks with output_notebook(notebook_type=’zeppelin’)
output_notebook()

# create a new plot with title and axis labels
fig = figure (title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line to plot
# - note how line thickness is set
# - names to be used in legend given
fig.line (x, y, legend="Temp.", line_width=2)

# show the results
show (fig)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5c51dc4e-6b81-4d11-b4c7-1b63f3d96d00">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fa23ddc9-32c9-4e63-9a09-6b75d0aae739"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fa23ddc9-32c9-4e63-9a09-6b75d0aae739");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fa23ddc9-32c9-4e63-9a09-6b75d0aae739");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fa23ddc9-32c9-4e63-9a09-6b75d0aae739' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ecc94a6d-2d1e-4dd0-afc8-ff34869834c2":{"roots":{"references":[{"attributes":{"plot":{"id":"63451e5a-afbc-4658-bc17-ba76cb5e1bb0","subtype":"Figure","type":"Plot"}},"id":"c5c058a2-c7ea-4002-aafa-fa9ffc0aba58","type":"SaveTool"},{"attributes":{},"id":"d336f3e1-7ea4-4388-9663-b830347a3faf","type":"BasicTicker"},{"attributes":{},"id":"3dbb5f1f-d4ea-4b06-bdc4-e95e21201670","type":"ToolEvents"},{"attributes":{"label":{"value":"Temp."},"renderers":[{"id":"a030efbe-b2bb-41cd-b186-e190cb6cde7f","type":"GlyphRenderer"}]},"id":"c0c3e7fa-7ce4-4ff9-9ab6-b3765d12fe19","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"a62d1352-5087-4495-a21b-91829cde0cdc","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"c59ad12d-6e02-4450-b519-a2b0b0e9abc2","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"732f1ec7-22ae-485e-bb04-eb482463a03a","type":"Line"},{"attributes":{"overlay":{"id":"032c3bc9-b3b3-4a9a-8c8b-23eb034d9a76","type":"BoxAnnotation"},"plot":{"id":"63451e5a-afbc-4658-bc17-ba76cb5e1bb0","subtype":"Figure","type":"Plot"}},"id":"ac251d74-81fa-41f1-b2fd-631ffdc0041e","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"f58e4a56-0566-462d-9a1b-af31391f68be","type":"DataRange1d"},{"attributes":{},"id":"f1741fb6-3afa-4271-b7a1-ca1452fd5da5","type":"BasicTickFormatter"},{"attributes":{"axis_label":"y","formatter":{"id":"f1741fb6-3afa-4271-b7a1-ca1452fd5da5","type":"BasicTickFormatter"},"plot":{"id":"63451e5a-afbc-4658-bc17-ba76cb5e1bb0","subtype":"Figure","type":"Plot"},"ticker":{"id":"70a0ef8c-b17b-4981-ac2f-5f2179d3aa3e","type":"BasicTicker"}},"id":"6a3926e6-72a5-47b7-97f7-6a23520a3361","type":"LinearAxis"},{"attributes":{"plot":{"id":"63451e5a-afbc-4658-bc17-ba76cb5e1bb0","subtype":"Figure","type":"Plot"}},"id":"1051356b-1db2-44ba-9fdb-78e881f2f878","type":"PanTool"},{"attributes":{"plot":{"id":"63451e5a-afbc-4658-bc17-ba76cb5e1bb0","subtype":"Figure","type":"Plot"},"ticker":{"id":"d336f3e1-7ea4-4388-9663-b830347a3faf","type":"BasicTicker"}},"id":"82dca34f-9755-4dc0-b448-c98d7dc9bd49","type":"Grid"},{"attributes":{"plot":{"id":"63451e5a-afbc-4658-bc17-ba76cb5e1bb0","subtype":"Figure","type":"Plot"}},"id":"4ce262d5-0bdc-408d-9232-ec2ce3f7268a","type":"WheelZoomTool"},{"attributes":{},"id":"70a0ef8c-b17b-4981-ac2f-5f2179d3aa3e","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"63451e5a-afbc-4658-bc17-ba76cb5e1bb0","subtype":"Figure","type":"Plot"},"ticker":{"id":"70a0ef8c-b17b-4981-ac2f-5f2179d3aa3e","type":"BasicTicker"}},"id":"c7b977fc-31cf-4282-a96d-1cfdb449a4b4","type":"Grid"},{"attributes":{"plot":null,"text":"simple line example"},"id":"aa4a7948-a99f-43e8-8d96-016e8bb91013","type":"Title"},{"attributes":{},"id":"05d0a63c-4dd3-46b0-96ba-76c098313b29","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"2d776c16-2147-4ea5-a61a-ecfe676d0e2b","type":"LinearAxis"}],"left":[{"id":"6a3926e6-72a5-47b7-97f7-6a23520a3361","type":"LinearAxis"}],"renderers":[{"id":"2d776c16-2147-4ea5-a61a-ecfe676d0e2b","type":"LinearAxis"},{"id":"82dca34f-9755-4dc0-b448-c98d7dc9bd49","type":"Grid"},{"id":"6a3926e6-72a5-47b7-97f7-6a23520a3361","type":"LinearAxis"},{"id":"c7b977fc-31cf-4282-a96d-1cfdb449a4b4","type":"Grid"},{"id":"032c3bc9-b3b3-4a9a-8c8b-23eb034d9a76","type":"BoxAnnotation"},{"id":"3cbc0852-ff4e-4dbd-8b95-b23c5bbe2f9d","type":"Legend"},{"id":"a030efbe-b2bb-41cd-b186-e190cb6cde7f","type":"GlyphRenderer"}],"title":{"id":"aa4a7948-a99f-43e8-8d96-016e8bb91013","type":"Title"},"tool_events":{"id":"3dbb5f1f-d4ea-4b06-bdc4-e95e21201670","type":"ToolEvents"},"toolbar":{"id":"acc33a05-c920-43fe-acdb-e1e0059ca87c","type":"Toolbar"},"x_range":{"id":"f58e4a56-0566-462d-9a1b-af31391f68be","type":"DataRange1d"},"y_range":{"id":"d7d6bfe3-1276 ...

# %% [markdown]
# Got some weirdness here where the previous save-to-static-file call is still being used. It stopped after a while so ...
#
# It seems the `output_X` call can be called almost any time before the `show` call.
#
# The `figure` call sets up the area to be drawn in (the plot), with ranges, labels and scales.
#
# You then call `line` (or other "renderers") to actually draw things (the data) on the figure.

# %% [markdown]
# A more complex example:

# %%
# prepare some data
x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y0 = [i**2 for i in x]
y1 = [10**i for i in x]
y2 = [10**(i**2) for i in x]

# once output_foo has been called, everything is sent to that destination

# create a new plot
# so you can choose the tools available 
p = figure (
   tools="resize,crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select",
   y_axis_type="log", y_range=[0.001, 10**11], title="log axis example",
   x_axis_label='sections', y_axis_label='particles',
   responsive=True, # fill the container
)

# Add various renderers
# - note how the legend represents the lines correctly
# - interesting that to get a line-with-circles plot, you create the two
#   two seperately and gives them the same data and title
p.line(x, x, legend="y=x")
p.circle(x, x, legend="y=x", fill_color="white", size=8)
p.line(x, y0, legend="y=x^2", line_width=3)
p.line(x, y1, legend="y=10^x", line_color="red")
p.circle(x, y1, legend="y=10^x", fill_color="red", line_color="red", size=6)
p.line(x, y2, legend="y=10^x^2", line_color="orange", line_dash="4 4")


# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cc009ce4-aaba-40e7-a325-6211a82bbbc3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cc009ce4-aaba-40e7-a325-6211a82bbbc3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cc009ce4-aaba-40e7-a325-6211a82bbbc3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cc009ce4-aaba-40e7-a325-6211a82bbbc3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6ce2699c-b88b-4185-8699-8fb90fbca8b7":{"roots":{"references":[{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":6},"x":{"field":"x"},"y":{"field":"y"}},"id":"490c37f5-3488-474e-b401-ed332a572d05","type":"Circle"},{"attributes":{"plot":null,"text":"log axis example"},"id":"3ebe8be6-9650-4d7f-9a76-33fe8070f7e9","type":"Title"},{"attributes":{},"id":"636396bf-d23d-4e2b-9d82-57041b169a07","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f747e191-bc45-41a8-bcdc-2571d1f2916f","type":"ResizeTool"},{"id":"825493b7-3e34-4756-b23b-0d015547de0b","type":"CrosshairTool"},{"id":"df3f1c1a-828d-4a7d-9d4e-64140f4d6216","type":"PanTool"},{"id":"c04f0e3f-8636-45e6-a4c5-1897bef731b8","type":"WheelZoomTool"},{"id":"0805570c-9cf2-4d27-b745-f08240dea0dd","type":"BoxZoomTool"},{"id":"1274754d-ba85-402b-aff8-1e39f184f297","type":"ResetTool"},{"id":"78f5c04c-8eae-43fd-80e1-fc9e54874c7a","type":"BoxSelectTool"},{"id":"8504eed1-b6e5-43c2-a4b3-353ff2c0e14f","type":"LassoSelectTool"}]},"id":"37bcfb70-0c47-46ef-a81a-3921a34b59ed","type":"Toolbar"},{"attributes":{"callback":null},"id":"637ddd17-a92b-4768-8015-7b3fe7fce256","type":"DataRange1d"},{"attributes":{"axis_label":"sections","formatter":{"id":"1df186a7-a467-49cd-93be-c9e0548ea720","type":"BasicTickFormatter"},"plot":{"id":"1ed6cfc9-1af2-44e3-b709-f46f0791eadc","subtype":"Figure","type":"Plot"},"ticker":{"id":"29f5e18f-5e59-4218-8521-f932e4a83d46","type":"BasicTicker"}},"id":"07c8a58f-8a59-47d6-a91a-91b1aa5e31b5","type":"LinearAxis"},{"attributes":{"callback":null,"end":100000000000,"start":0.001},"id":"522837ad-1bee-4d78-bd63-c375b9762946","type":"Range1d"},{"attributes":{},"id":"29f5e18f-5e59-4218-8521-f932e4a83d46","type":"BasicTicker"},{"attributes":{"plot":{"id":"1ed6cfc9-1af2-44e3-b709-f46f0791eadc","subtype":"Figure","type":"Plot"},"ticker":{"id":"29f5e18f-5e59-4218-8521-f932e4a83d46","type":"BasicTicker"}},"id":"eee3c07c-468e-405a-a260-16f8549480e2","type":"Grid"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"77842ae9-50b1-4fed-8a30-8e6b056a0fbd","type":"Line"},{"attributes":{"axis_label":"particles","formatter":{"id":"98b59430-9513-42aa-9689-15fc7b2f6e21","type":"LogTickFormatter"},"plot":{"id":"1ed6cfc9-1af2-44e3-b709-f46f0791eadc","subtype":"Figure","type":"Plot"},"ticker":{"id":"9b2b23d4-7467-488b-9ff1-a658a7b637da","type":"LogTicker"}},"id":"0260e6f6-30f7-4207-8b5f-a38fc7d7fe13","type":"LogAxis"},{"attributes":{},"id":"1df186a7-a467-49cd-93be-c9e0548ea720","type":"BasicTickFormatter"},{"attributes":{"num_minor_ticks":10},"id":"9b2b23d4-7467-488b-9ff1-a658a7b637da","type":"LogTicker"},{"attributes":{"dimension":1,"plot":{"id":"1ed6cfc9-1af2-44e3-b709-f46f0791eadc","subtype":"Figure","type":"Plot"},"ticker":{"id":"9b2b23d4-7467-488b-9ff1-a658a7b637da","type":"LogTicker"}},"id":"3a065ae5-59b5-4bd0-af12-f58143b3290b","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4951937f-7347-477d-9333-0f8ba62ff1ca","type":"Line"},{"attributes":{"label":{"value":"y=x^2"},"renderers":[{"id":"9cd998da-afcc-40cc-9d70-f417485ab6bb","type":"GlyphRenderer"}]},"id":"9e8ad6d5-7f07-42ff-8d5e-7a43ac8a0814","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"785b6785-bc9d-4ad2-8ea1-62d3933078dc","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.1,0.5,1.0,1.5,2.0,2.5,3.0],"y":[0.010000000000000002,0.25,1.0,2.25,4.0,6.25,9.0]}},"id":"745b32d3-eec0-4579-a8ee-31b60eed9674","type":"ColumnDataSource"},{"attributes":{" ...

# %% [markdown]
# ## Styling

# %%
# you can give specific plot dimensions. although bokeh generally makes better choices
p = figure (plot_width=400, plot_height=400)
p.circle([1,2,3,4,5], [2,5,8,2,7], size=10)

# change some things about the x-axes
p.xaxis.axis_label = "Temp"
p.xaxis.axis_line_width = 3
p.xaxis.axis_line_color = (200, 100, 100)

# change just some things about the y-axes
p.yaxis.axis_label = "Pressure"
p.yaxis.major_label_text_color = "#aa6666"
p.yaxis.major_label_orientation = "vertical"

# note how you can change things on all axes
p.axis.minor_tick_in = -3
p.axis.minor_tick_out = 6

# do some title styling
p.title.text_font_size = "3.0em" # can be px, em or pt
p.title.align = 'center'
p.title.text_color = "olive"
p.title.text_font = "times, georgia"
p.title.text_font_style = "italic"

# set the background of the plot
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5

# set the border (region outside the plot)
p.border_fill_color = "whitesmoke"
p.min_border_left = p.min_border_right = p.min_border_top = p.min_border_bottom = 80

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="65aca066-f932-4639-8252-bf1c811b1a03"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("65aca066-f932-4639-8252-bf1c811b1a03");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("65aca066-f932-4639-8252-bf1c811b1a03");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '65aca066-f932-4639-8252-bf1c811b1a03' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ea437282-12c9-474e-b369-a001637122d7":{"roots":{"references":[{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"a3aa3009-d16d-4e25-b420-dbd5fd15588a","type":"LinearAxis"}],"border_fill_color":{"value":"whitesmoke"},"left":[{"id":"66b20b43-1154-48ce-9a4a-bedffd546515","type":"LinearAxis"}],"min_border_bottom":80,"min_border_left":80,"min_border_right":80,"min_border_top":80,"plot_height":400,"plot_width":400,"renderers":[{"id":"a3aa3009-d16d-4e25-b420-dbd5fd15588a","type":"LinearAxis"},{"id":"c83966e5-288f-49b1-9694-197ea2046dd9","type":"Grid"},{"id":"66b20b43-1154-48ce-9a4a-bedffd546515","type":"LinearAxis"},{"id":"f1628513-53d6-4202-bf91-d65028d6951e","type":"Grid"},{"id":"7112e6cd-6913-424c-8dcf-2779bda9be1b","type":"BoxAnnotation"},{"id":"212640a3-c7f8-4d65-97b2-c7f7e78a9aaf","type":"GlyphRenderer"}],"title":{"id":"36512f24-5c61-4ad6-ba14-a5958bc5f3c1","type":"Title"},"tool_events":{"id":"6d1a4b7f-dca4-490e-82bc-6e6018a272b4","type":"ToolEvents"},"toolbar":{"id":"fb613f79-33e7-46b5-a504-7b2db68fff9a","type":"Toolbar"},"x_range":{"id":"92529241-85fb-4bc2-bcb5-8e309bd0c732","type":"DataRange1d"},"y_range":{"id":"479dd04b-c1d3-4f54-9b75-0835e76b1819","type":"DataRange1d"}},"id":"52dd1182-cb25-44f6-b924-098117e36faa","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"Pressure","formatter":{"id":"a16b73df-4c59-4586-913a-d76b6486d1f5","type":"BasicTickFormatter"},"major_label_orientation":"vertical","major_label_text_color":{"value":"#aa6666"},"minor_tick_in":-3,"minor_tick_out":6,"plot":{"id":"52dd1182-cb25-44f6-b924-098117e36faa","subtype":"Figure","type":"Plot"},"ticker":{"id":"375ca6d4-3265-493a-8730-964dfe848806","type":"BasicTicker"}},"id":"66b20b43-1154-48ce-9a4a-bedffd546515","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":[2,5,8,2,7]}},"id":"68269cc2-d8b0-4f2c-ac4e-98dce0595ce2","type":"ColumnDataSource"},{"attributes":{},"id":"375ca6d4-3265-493a-8730-964dfe848806","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"e43e6819-e92d-4c98-9452-783e3ed91573","type":"Circle"},{"attributes":{"plot":{"id":"52dd1182-cb25-44f6-b924-098117e36faa","subtype":"Figure","type":"Plot"}},"id":"b83b1966-bfb8-4d82-a9c0-2e658aaa7c7a","type":"HelpTool"},{"attributes":{},"id":"6d1a4b7f-dca4-490e-82bc-6e6018a272b4","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"52dd1182-cb25-44f6-b924-098117e36faa","subtype":"Figure","type":"Plot"},"ticker":{"id":"375ca6d4-3265-493a-8730-964dfe848806","type":"BasicTicker"}},"id":"f1628513-53d6-4202-bf91-d65028d6951e","type":"Grid"},{"attributes":{"plot":{"id":"52dd1182-cb25-44f6-b924-098117e36faa","subtype":"Figure","type":"Plot"},"ticker":{"id":"c335cd42-8cfe-4a91-9a25-40103eb4b9bc","type":"BasicTicker"}},"id":"c83966e5-288f-49b1-9694-197ea2046dd9","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"5b18a7a6-3cdb-4548-b695-6d6004e7094a","type":"Circle"},{"attributes":{},"id":"a16b73df-4c59-4586-913a-d76b6486d1f5","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7112e6cd-6913-424c-8dcf-2779bda9be1b","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"52dd1182-cb25-44f6-b924-098117e36faa","subtype":"Figure","type":"Plot"}},"id":"2863ca2c-113d-472f-8a7a-861df407eca9","type":"PanTool"},{"attributes":{},"id":"a572188b-2ac1-4766-8b55-e3fac ...

# %% [markdown]
# ## Tools

# %% [markdown]
# Plot tools come in three basic types, determined by interaction. Only one one any type can be active at any point (and is highlighted in the toolbar):
#
#   * Pan / drag: move around the plot or select parts of plot
#     * `box_select`: select (highlight) points with a box
#     * `lasso_select`: select points in an irregular area
#     * `box_zoom`: zoom in on a section of data
#     * `pan`, `xpan`, `ypan`: pan side to side and up and down in data
#     * resize: resize the whole plot
#   * Click / tap: using mouse clicks
#     * `tap`: select individual points
#     * `poly_select`: select points in an arbitrary polygon
#   * Scroll / pinch: use the scrollwheel on a mouse
#     * 'wheel_zoom', 'xwheel_zoom', 'ywheel_zoom': zoom in and out
#     * 'xwheel_pan', 'ywheel_pan': pan vertically or horizontally
#   * Actions: happen instantly when button clicked
#     * undo
#     * redo
#     * reset: reet to original / normal viz
#     * 'zoom_in', 'xzoom_in', 'yzoom_in'
#     * 'zoom_out', 'xzoom_out', 'yzoom_out'
#     * crosshair: a plot resizer that works by zooming in on a point?
#     * save

# %%
# use the above data
x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y0 = [i**2 for i in x]
y1 = [10**i for i in x]
y2 = [10**(i**2) for i in x]

# create a new plot

p = figure (
    # choose tools available
    # note this doesn't choose the order
    tools="resize,crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select",
    # choose toolbar location
    toolbar_location="above",
    title="tool example",
)

# Add various renderers
p.line (x, x, legend="y=x")
p.circle (x, x, legend="y=x", fill_color="white", size=8)
p.line (x, y0, legend="y=x^2", line_width=3)
p.line (x, y1, legend="y=10^x", line_color="red")
p.circle (x, y1, legend="y=10^x", fill_color="red", line_color="red", size=6)
p.line (x, y2, legend="y=10^x^2", line_color="orange", line_dash="4 4")


# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c29686fc-826b-4eaa-b2f2-f560842d0b44"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c29686fc-826b-4eaa-b2f2-f560842d0b44");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c29686fc-826b-4eaa-b2f2-f560842d0b44");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c29686fc-826b-4eaa-b2f2-f560842d0b44' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"02f9af49-cfaf-4b72-befa-d802277af0d2":{"roots":{"references":[{"attributes":{"callback":null,"overlay":{"id":"4e2e5a49-24df-4d96-81af-7dfb3df21d06","type":"PolyAnnotation"},"plot":{"id":"80cc2267-a22c-485e-a5d3-6ff6955bc0f6","subtype":"Figure","type":"Plot"}},"id":"2d78546c-d55e-4184-9df9-e2ebcb6dc9a2","type":"LassoSelectTool"},{"attributes":{"label":{"value":"y=x^2"},"renderers":[{"id":"f235155a-998f-46d8-adf3-3253087c183c","type":"GlyphRenderer"}]},"id":"113d60f7-3bcc-4265-97b6-2dec323f807f","type":"LegendItem"},{"attributes":{"label":{"value":"y=x"},"renderers":[{"id":"9acd051e-c109-4cbc-826d-c87f7daf026f","type":"GlyphRenderer"},{"id":"95cd6557-15c8-4a50-a4eb-5a68f5926e9b","type":"GlyphRenderer"}]},"id":"d384aaf4-0400-4fc5-ae42-95baf59a2d95","type":"LegendItem"},{"attributes":{"data_source":{"id":"20e2a7e3-bed1-4898-851a-89f8c83044a0","type":"ColumnDataSource"},"glyph":{"id":"0323e9d6-9846-43ae-aa4d-c4b6e513ebb2","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"871a4990-58f2-4b00-b593-3f57ce81df23","type":"Line"},"selection_glyph":null},"id":"121553d4-ece0-4c3f-9ad4-a4e29e9c4a5c","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"b18f2926-0050-4039-b820-eed0de806aa5","type":"BasicTickFormatter"},"plot":{"id":"80cc2267-a22c-485e-a5d3-6ff6955bc0f6","subtype":"Figure","type":"Plot"},"ticker":{"id":"68412c55-8b93-4eec-8dda-f9f3b1dde2a0","type":"BasicTicker"}},"id":"5a36e367-dbf3-402b-96c1-2ed3b833121e","type":"LinearAxis"},{"attributes":{"data_source":{"id":"37227a32-1c02-4d4f-a99c-d5cb7b435992","type":"ColumnDataSource"},"glyph":{"id":"2e44407a-45fb-400d-8254-f9fff7a89557","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7c28a3d5-8448-4e9c-aa91-fe5f7448646d","type":"Line"},"selection_glyph":null},"id":"51ca26f1-604f-4e1a-a2a2-600a9408d5b5","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"orange"},"line_dash":[4,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"0323e9d6-9846-43ae-aa4d-c4b6e513ebb2","type":"Line"},{"attributes":{"plot":{"id":"80cc2267-a22c-485e-a5d3-6ff6955bc0f6","subtype":"Figure","type":"Plot"}},"id":"397b78e9-a613-45c6-94dd-5b8713c196b9","type":"PanTool"},{"attributes":{"label":{"value":"y=10^x^2"},"renderers":[{"id":"121553d4-ece0-4c3f-9ad4-a4e29e9c4a5c","type":"GlyphRenderer"}]},"id":"c25c4dfd-1513-4df1-8b14-0b821958d43b","type":"LegendItem"},{"attributes":{"overlay":{"id":"415e6b3a-07b7-4a3d-9ae5-1fb765ea60ed","type":"BoxAnnotation"},"plot":{"id":"80cc2267-a22c-485e-a5d3-6ff6955bc0f6","subtype":"Figure","type":"Plot"}},"id":"d7c6f4d8-03c8-4e13-967d-ab8863c2dbc8","type":"BoxZoomTool"},{"attributes":{"callback":null,"overlay":{"id":"c27c5e29-e26d-4987-98b7-fc7c9c35eb97","type":"BoxAnnotation"},"plot":{"id":"80cc2267-a22c-485e-a5d3-6ff6955bc0f6","subtype":"Figure","type":"Plot"},"renderers":[{"id":"9acd051e-c109-4cbc-826d-c87f7daf026f","type":"GlyphRenderer"},{"id":"95cd6557-15c8-4a50-a4eb-5a68f5926e9b","type":"GlyphRenderer"},{"id":"f235155a-998f-46d8-adf3-3253087c183c","type":"GlyphRenderer"},{"id":"51ca26f1-604f-4e1a-a2a2-600a9408d5b5","type":"GlyphRenderer"},{"id":"70f7e916-833e-4715-a5e5-2b8440e62405","type":"GlyphRenderer"},{"id":"121553d4-ece0-4c3f-9ad4-a4e29e9c4a5c","type":"GlyphRenderer"}]},"id":"caecdfe5-1e32-4ae9-8512-4b781e7aad10","type":"BoxSelectTool"},{"attributes":{"data_source":{"id":"1adaa62f-a04e-40c3-925e-f12e77155727","type":"ColumnDataSource"},"glyph":{"id":"a426deb2-fd97-4be3-8553-c860309852bf","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1b1bcb5d-3a7d-4878-a6c1-2abc1f82eb5c","type":"Line"},"selection_glyph":null},"id":"f235155a-998f-46d8-adf3-3253087c183c","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"a426deb2-fd97-4be3-8553-c860309852bf","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value": ...

# %% [markdown]
# ## Export & saving

# %% [markdown]
# Headless export is possible but requires other dependencies to be installed (see http://bokeh.pydata.org/en/latest/docs/user_guide/export.html).
#
# Alternatively, PhantomJS (via a Chrome bookmarklet) can be used to take a PDf screenshot.

# %%
# output to a static HTML file
output_file ("plot.html")

# everything elese is done as per normal
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

file_fig = figure()
file_fig.line (x, y)

# create & open the external file
show (file_fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ab6674c8-385d-47e7-bc36-39dfea0f681d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ab6674c8-385d-47e7-bc36-39dfea0f681d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ab6674c8-385d-47e7-bc36-39dfea0f681d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ab6674c8-385d-47e7-bc36-39dfea0f681d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d0a2e087-30a0-48ac-9812-e711f439459d":{"roots":{"references":[{"attributes":{"plot":{"id":"32e82905-66cb-473b-b0a0-b3f9b4216760","subtype":"Figure","type":"Plot"}},"id":"2448b765-f3f4-4cc0-8fda-ffe3c554abff","type":"SaveTool"},{"attributes":{"plot":{"id":"32e82905-66cb-473b-b0a0-b3f9b4216760","subtype":"Figure","type":"Plot"}},"id":"46c77646-2582-4e92-90ed-bac57bf8553b","type":"HelpTool"},{"attributes":{"plot":{"id":"32e82905-66cb-473b-b0a0-b3f9b4216760","subtype":"Figure","type":"Plot"}},"id":"771eb600-9d90-4443-abdc-c251c4105895","type":"WheelZoomTool"},{"attributes":{},"id":"e3c0bb4e-0275-4185-9412-19973591534d","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"fb625ee8-f2a5-48ee-bdb7-cb952b12eb92","type":"ColumnDataSource"},{"attributes":{},"id":"a1240582-64d7-47a6-9e6c-8bbc7223e1f6","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"32e82905-66cb-473b-b0a0-b3f9b4216760","subtype":"Figure","type":"Plot"}},"id":"e23f9d0f-a4ba-4b39-ba36-92969462e9e1","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8793a050-0ddf-46a4-ab47-ef39e972241b","type":"Line"},{"attributes":{"formatter":{"id":"a1240582-64d7-47a6-9e6c-8bbc7223e1f6","type":"BasicTickFormatter"},"plot":{"id":"32e82905-66cb-473b-b0a0-b3f9b4216760","subtype":"Figure","type":"Plot"},"ticker":{"id":"a54c7c3d-da86-4aeb-b741-aab9d8a48e5a","type":"BasicTicker"}},"id":"dd763ae7-b751-45c5-aa10-4301d534202a","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"32e82905-66cb-473b-b0a0-b3f9b4216760","subtype":"Figure","type":"Plot"},"ticker":{"id":"a54c7c3d-da86-4aeb-b741-aab9d8a48e5a","type":"BasicTicker"}},"id":"bab4c889-8537-490e-9b6c-8d5ffc4d144f","type":"Grid"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"476daa0e-3e1b-4a28-8a4a-c9cac2e81986","type":"Line"},{"attributes":{"plot":{"id":"32e82905-66cb-473b-b0a0-b3f9b4216760","subtype":"Figure","type":"Plot"},"ticker":{"id":"708249a8-ab27-4c0c-9c6e-f6d99e5a5c6c","type":"BasicTicker"}},"id":"c0c232f3-c290-4d62-9ff4-f745e7f37c15","type":"Grid"},{"attributes":{"callback":null},"id":"bcbabb76-30dd-4da4-ad5c-46de013ac6a4","type":"DataRange1d"},{"attributes":{},"id":"708249a8-ab27-4c0c-9c6e-f6d99e5a5c6c","type":"BasicTicker"},{"attributes":{"callback":null},"id":"c1506d73-a0b0-4c60-a8d4-7b5c604853e1","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"ac738ee7-ed9e-4754-9db8-5b5a1acf56af","type":"Title"},{"attributes":{"data_source":{"id":"fb625ee8-f2a5-48ee-bdb7-cb952b12eb92","type":"ColumnDataSource"},"glyph":{"id":"476daa0e-3e1b-4a28-8a4a-c9cac2e81986","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8793a050-0ddf-46a4-ab47-ef39e972241b","type":"Line"},"selection_glyph":null},"id":"21b600e7-7465-4a95-b374-09a8e8ad8e45","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e23f9d0f-a4ba-4b39-ba36-92969462e9e1","type":"PanTool"},{"id":"771eb600-9d90-4443-abdc-c251c4105895","type":"WheelZoomTool"},{"id":"c60fb62a-c627-4d1f-b2d1-917fe9686cfc","type":"BoxZoomTool"},{"id":"2448b765-f3f4-4cc0-8fda-ffe3c554abff","type":"SaveTool"},{"id":"be5f4f78-6ae5-4525-bc78-a88768eee4c8","type":"ResetTool"},{"id":"46c77646-2582-4e92-90ed-bac57bf8553b","type":"HelpTool"}]},"id":"4a73322d-5088-4874-b02a-e4cf62c33ba9","type":"Toolbar"},{"attributes":{"formatter":{"id":"0ee8cc5c-cfb1-4462-ab6f-83d1623a8c8a","type":"BasicTickFormatter"},"plot":{"id":"32e82905-66cb-473b-b0a0-b3f9b4216760","subtype":"Figure","type":"Plot"},"ticker":{"id":"708249a8-ab27-4c0c-9c6e-f6d99e5a5c6c","type":"BasicTicker"}},"id":"43111192-d9ba-47a5-9e38-edb207b577a4","type":"LinearAxis"},{"attributes":{"plot":{"id":"32e82905-66cb-473b-b0a0-b3f9b4216760","subtype":"Figure","type":"Plot"}},"id":"be5f4f78-6ae5-4525-bc78-a88768eee ...

# %% [markdown]
# # Random notes

# %% [markdown]
# * There's also Bokeh for Scala & Julia
# * HTML will load the JS from a CDN. However there are ways of packaging a self-contained page
# * There are various attributes you can set on a plot to improve performance, mostly needed if you're interactiing wiht a plot containing many points.
